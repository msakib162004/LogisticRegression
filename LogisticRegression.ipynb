# %%
import pandas as pd
from pandas.api.types import is_string_dtype

data = pd.read_csv('adult.csv', na_values='?')

# %%
data
# Out:
#       age         work-class  fnlwgt  ... hours-per-week  native-country  salary
# 0      39          State-gov   77516  ...           40.0   United-States   <=50K
# 1      50   Self-emp-not-inc   83311  ...           13.0   United-States   <=50K
# 2      38            Private  215646  ...           40.0   United-States   <=50K
# 3      53            Private  234721  ...           40.0   United-States   <=50K
# 4      28            Private  338409  ...           40.0            Cuba   <=50K
# ...    ..                ...     ...  ...            ...             ...     ...
# 38471  27            Private  257302  ...           38.0   United-States   <=50K
# 38472  40            Private  154374  ...           40.0   United-States    >50K
# 38473  58            Private  151910  ...           40.0   United-States   <=50K
# 38474  22            Private  201490  ...           20.0   United-States   <=50K
# 38475  52       Self-emp-inc  287927  ...           40.0   United-States    >50K
#
# [38476 rows x 15 columns]

# %%
from sklearn.preprocessing import Binarizer
cont_col = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
b_data = pd.DataFrame()

for col in data.columns:
  if col in cont_col:
    bin = Binarizer(threshold=data[col].mean())
    b_data[col] = bin.transform(data[[col]]).flatten()
  else:
    b_data[col] = data[col].copy()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1426         try:
# -> 1427             x = float(x)
#    1428         except ValueError:
#
# ValueError: could not convert string to float: '......
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1430             try:
# -> 1431                 x = complex(x)
#    1432             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-4975d49f4643> in <module>()
#       5 for col in data.columns:
#       6   if col in cont_col:
# ----> 7     bin = Binarizer(threshold=data[col].mean())
#       8     b_data[col] = bin.transform(data[[col]]).flatten()
#       9   else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11473             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11474         return self._reduce(
# > 11475             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11476         )
#   11477
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4247                 )
#    4248             with np.errstate(all="ignore"):
# -> 4249                 return op(delegate, skipna=skipna, **kwds)
#    4250
#    4251     def _reindex_indexer(self, new_index, indexer, copy):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     561         dtype_count = dtype
#     562     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 563     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     564
#     565     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1432             except ValueError as err:
#    1433                 # e.g. "foo"
# -> 1434                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1435     return x
#    1436
#
# TypeError: Could not convert ......

# %%
b_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

data = pd.get_dummies(b_data, drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-cd6bcc9f2b70> in <module>()
#       3 from sklearn.model_selection import train_test_split
#       4
# ----> 5 data = pd.get_dummies(b_data, drop_first=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     897             )
#     898             with_dummies.append(dummy)
# --> 899         result = concat(with_dummies, axis=1)
#     900     else:
#     901         result = _get_dummies_1d(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     282         verify_integrity=verify_integrity,
#     283         copy=copy,
# --> 284         sort=sort,
#     285     )
#     286
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     329
#     330         if len(objs) == 0:
# --> 331             raise ValueError("No objects to concatenate")
#     332
#     333         if keys is None:
#
# ValueError: No objects to concatenate

# %%
data
# Out:
#        age  fnlwgt  ...  native-country_ Yugoslavia  salary_ >50K
# 0        1       0  ...                           0             0
# 1        1       0  ...                           0             0
# 2        0       1  ...                           0             0
# 3        1       1  ...                           0             0
# 4        0       1  ...                           0             0
# ...    ...     ...  ...                         ...           ...
# 32556    0       1  ...                           0             0
# 32557    1       0  ...                           0             1
# 32558    1       0  ...                           0             0
# 32559    0       1  ...                           0             0
# 32560    1       1  ...                           0             1
#
# [32561 rows x 101 columns]

# %%
train_x, test_x, train_y, test_y = train_test_split(data.drop('salary_ >50K', axis=1), data['salary_ >50K'], train_size=0.85)

# %%
train_y
# Out:
# 27298    0
# 22227    1
# 22195    0
# 15639    0
# 31135    0
#         ..
# 11517    0
# 2244     0
# 1252     0
# 10993    0
# 11862    0
# Name: salary_ >50K, Length: 27676, dtype: uint8

# %%
Log_Reg = LogisticRegression()
Log_Reg.fit(train_x, train_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import accuracy_score, f1_score

acc = Log_Reg.predict(test_x)

# %%
acc1 = accuracy_score(test_y, acc)
f11 = f1_score(test_y, acc)

# %%
print(acc1, f11)
# Out:
# 0.8462640736949847 0.6359670382937469
